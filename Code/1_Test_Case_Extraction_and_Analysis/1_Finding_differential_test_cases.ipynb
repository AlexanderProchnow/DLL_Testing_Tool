# %% [markdown]
# # Finding differential test cases
#
# The goal of this notebook is to identify and extract all differential test cases and store the functions that are used as oracles. These functions can then be checked for changes whenever developers make a new commit that the tool's user might want to know about.

# %% [markdown]
# ## Imports

# %%
import ast
import sys
import numpy as np
import os
from datetime import datetime
from tqdm import tqdm
import copy

# %% [markdown]
# ## Import source code and create Abstract Syntax Tree
#
#
# An abstract syntax tree represents source code as a tree, where each node is an element of the source code, e.g. a function definition, function call, if-else statement, while-loop, variable assignment etc. It abstracts away e.g. grouping parentheses, because these groupings are implicitly defined in the tree's structure.
#
# <img style="float: right;" src="images/abstract_syntax_tree.png" width="450">
#
# This code produces the following tree:
# ```
# while b ≠ 0
#   if a > b
#     a := a − b
#   else
#     b := b − a
# return a
# ```
#
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <div style="text-align: right"> <i> Source https://en.wikipedia.org/wiki/Abstract_syntax_tree </i> </div>

# %% [markdown]
# ### Setup: Edit this code cell and replace the library root with the equivalent file path on your machine
# Comment in the library you want to extract the test cases from.
# The specific python files here are debugging on a single file.

# %%
# Set library root folder:

# For TensorFlow
#library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/Tensorflow/tensorflow-master/tensorflow/python/" 
#save_data_to = "extracted_data/tensorflow_data.csv"

# For TensorFlow 1.12.0
library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/Tensorflow/tensorflow-1.12.0/tensorflow/python/" 
save_data_to = "extracted_data/tensorflow_1.12.0__TESTING_data.csv"

# For Keras
#save_data_to = "extracted_data/keras_data.csv"

# For Pytorch
#library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/PyTorch/pytorch-master/" 
#save_data_to = "extracted_data/pytorch_data.csv"

# For Theano 1.0.3
#library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/Theano-rel-1.0.3/theano"
#save_data_to = "extracted_data/theano_data.csv"

# For Aesara
#library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/Aesara/aesara-main/"
#tests_root = "tests"
#save_data_to = "extracted_data/aesara_data.csv"

# For Scipy
#library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/Scipy/scipy-master/scipy"
#save_data_to = "extracted_data/scipy_data.csv"

# For Numpy
#library_root = "A:/BachelorThesis/DLL_Testing_Tool/DL_Libraries/Numpy/numpy-main/numpy"
#save_data_to = "extracted_data/numpy_data.csv"

# set python source file (for single file debugging):

# TensorFlow:
#source = open(library_root + "kernel_tests/rnn_test.py")
source = open(library_root + "kernel_tests/distributions/gamma_test.py")
#source = open(library_root + "kernel_tests/matrix_solve_op_test.py")
#source = open(library_root + "kernel_tests/distributions/student_t_test.py", encoding="utf8")
#source = open(library_root + "kernel_tests/reduction_ops_test.py")

# files with test cases that are not covered yet
#source = open(library_root + "kernel_tests/array_ops_test.py")

# New errors:
#source = open(library_root + "kernel_tests/boosted_trees/prediction_ops_test.py")
#source = open(library_root + tests_root + "/lookup_ops_test.py")
#source = open(library_root + tests_root + "/random/random_gamma_test.py")

# Binary Ops:
#source = open(library_root + tests_root + "/conv1d_transpose_test.py")

# Constant:
#source = open(library_root + tests_root + "/distributions/uniform_test.py")

# Name:
#source = open(library_root + tests_root + "/candidate_sampler_ops_test.py")

# Function on file level
#source = open(library_root + tests_root + "/distributions/bernoulli_test.py")

# TODO Difficult case: Creates dicts and compares them to ones created with numpy and scipy
#source = open(library_root + tests_root + "/signal\dct_ops_test.py")

# Keras:
#source = open(library_root + tests_root + "/model_architectures_test.py")


# PyTorch:
#source = open(library_root + "test/distributions/test_distributions.py")
#source = open(library_root + tests_root + "\\distributed\\optim\\test_zero_redundancy_optimizer.py")
#source = open(library_root + tests_root + "/distributed/elastic/timer/local_timer_test.py")

# Theano:
#source = open(library_root + "/tests/test_gradient.py")

# Aesara: 
#source = open(library_root + tests_root + "/diverse_tests.py")

# Scipy: 
#source = open(library_root + "/stats/tests/common_tests.py")

# Numpy:
#source = open(library_root + "/polynomial/tests/test_polynomial.py")

# generate abstract syntax tree
tree = ast.parse(source.read())

# %% [markdown]
# ## Identify assert function calls and check if the arguments are differential test oracles

# %% [markdown]
# Here we define which assert statements are relevant for us.

# %%
# Define which assert functions to look for
approximation_asserts = ["assertAlmostEqual", "assertAlmostEquals", "assertAllClose", "assertAllLessEqual",
                         "assertAllCloseAccordingToType", "assertArrayNear", "assert_list_pairwise",
                         "assertNear", "assertLess", "assertAllLess", "assertLessEqual", 
                         "assertNDArrayNear", "assert_allclose", "assert_array_almost_equal",
                         "assert_almost_equal","assert_array_less", 
                         "isclose", "allclose", "gradcheck", "gradgradcheck"]

bool_asserts = ["assertTrue", "assertFalse","assertIs","assertIsNot"]

other_asserts = ["assertAllEqual","assertEquals", "assertEqual", "assertAllGreater",
                                                          "assertAllGreaterEqual", "assertAllInRange", "assertAllInSet",
                                                          "assertCountEqual", "assertDTypeEqual", "assertDictEqual",
                                                          "assertSequenceEqual", "assertShapeEqual",
                                                          "assertTupleEqual", "assert_array_equal"]

numpy_asserts = ["assert_raises", "assert_equal", "assert_",
    "assert_warns", "assert_raises_regex"]

all_asserts = approximation_asserts + bool_asserts + other_asserts + numpy_asserts

# %% [markdown]
# ### Create a custom printer/logger for later debugging

# %%
LOG_ALL = 0
LOG_FINAL = 1
LOG_NONE = 2

class CustomLogger():
    def __init__(self, print_mode=LOG_FINAL, log_mode=LOG_ALL):
        """Open Log and set print mode. LOG_FINAL prints only output for users. Other log modes are for debugging."""
        self.print_mode = print_mode
        self.log_mode = log_mode
        
        # for creating a csv with the collected data
        self.file_path = ""
        #self.data = np.array(["File Path", "Line Number", "Found in Function", "Function Definition Line Number" "Assert Statement Type", "Oracle Argument Position", "Differential Function Line Number", "Differential Test Function"])
        self.data = np.array(["File_Path", "Line_Number", "Found_in_Function", "Function_Definition_Line_Number", "Assert_Statement_Type", "Oracle_Argument_ Position", "Differential_Function_Line_Number", "Differential_Test_Function"])
    
        # create a .txt log file
        if not os.path.exists("extraction_logs"):
            os.mkdir("extraction_logs")
        logfile_name = "extraction_logs/" + "log_" + datetime.now().strftime("%d_%b_%Y__%H_%M") + ".txt"
        # open the log file in append mode, create it if it does not exist
        self.log = open(logfile_name, 'a+')
        
    def add(self, string, mode=LOG_ALL, end='\n'):
        """Add text to the log and print if it matches the chosen print_mode"""
        #TODO Write log to txt file (for the full tool later) 
        
        # print the string if print mode matches
        if mode >= self.print_mode:
            print(string, end=end)
            
        if mode >= self.log_mode:
            self.log.write(string + end)
    
    def createEntry(self, line_no, found_in_function, function_def_line_no, assert_statement_type, oracle_arg_pos, diff_func_line_no, diff_test_function_name):
        """Add an entry to the data."""
        self.data = np.vstack((self.data, [self.file_path, line_no, found_in_function, function_def_line_no, assert_statement_type, oracle_arg_pos, diff_func_line_no, diff_test_function_name]))
    
    def set_file_path_variable(self, file_path):
        """Set the file path variable for upcoming data entries."""
        self.file_path = file_path
        
    def get_data(self):
        return self.data
    
    def save_data_to_csv(self, path="extracted_data/data.csv"):
        os.makedirs(os.path.dirname(path), exist_ok=True)
        np.savetxt(path, self.data, fmt='%s', delimiter=",")
        print("Data saved to " + path)
        # close log
        self.log.close()

# %% [markdown]
# ### Traversing the tree via NodeVisitor
#
# Since we are only interested in functions calls within the library's testing code, we use `visit_Call` to check each function call node if it is (1) an assert call and (2) if it uses a differential test oracle, i.e. another function call for comparison.
#
# As an example we will use the `kernel_tests/distributions/gamma_test.py` file of TensorFlow version [2.5.0](https://github.com/tensorflow/tensorflow/releases/tag/v2.5.0), which tests the gamma distribution functions.
# In this file there are many differential test cases. For example the assert statements in lines 77 and 143 are both differntial tests.
#
# The `gamma_test` file uses the scipy library for differential testing. Many test cases in this file, for example the function `testGammaLogPDF` compares some part of TensorFlows own `tensorflow.python.ops.distributions.gamma` to the corresponding part in `scipy.stats.gamma`, e.g. comparing both log probability density functions at multiple points.
#
# TODO Explain how we can detect a differential oracle in the AST (i.e. by finding the stats function used as comparison)
# TODO Trail back the oracle to a definition outside the function call, because the oracle might be an argument in the function definition
#
# *Resource ast https://greentreesnakes.readthedocs.io/en/latest/manipulating.html*
# *Resource astor https://astor.readthedocs.io/en/latest/*

# %%
class TreeTraverser(ast.NodeVisitor):
    def __init__(self, tree):
        
        # store the parsed source file
        self.tree = tree
        
        # always stores the last function definition node that was visited along with its arguments
        self.last_function_definition_node = None
        self.last_func_arg_list = []
        
        # variables to ignore when recursively tracing back variable definitions 
        self.ignore_list = []
        # record all nodes visited to avoid recursion loops
        self.nodes_visited = []
        
    def visit_Call(self, node):
        
        # (1) Identify if it is an assert call that we are looking for:    
        assert_statement = ""
        
        # for nodes that call a function of an object, e.g. self.assert(...)
        if isinstance(node.func, ast.Attribute):
            assert_statement = node.func.attr
            
        # or directly, e.g. assert_(...)    
        elif isinstance(node.func, ast.Name):
            assert_statement = node.func.id
            
            
        # if the name of the called function is one we are searching for
        if assert_statement in all_asserts:

            # print the assert function name and line number
            log.add("______________" + assert_statement + "__(line " + str(node.lineno) + ")______________", mode=LOG_FINAL)

            # print the node and its structure
            log.add(ast.dump(node, indent='\t') + '\n')
            log.add("Found in: " + self.last_function_definition_node.name)

            # (2) Identify if the assert call uses a differential test oracle:

            # Go through arguments of the assert call (only the first two, other arguments are tolerances)
            for argument_position, assert_argument in enumerate(node.args[:2]):

                # have argument positions as position 1, position 2 etc.
                _argument_position = argument_position+1

                # reflect in the log which argument is currently being looked at
                log.add("\nArgument " + str(_argument_position) + ": ")

                # return the definitions of the arguments to check if they are differential testing functions
                arg_definitions = self._getDefinition(assert_argument)

                # check which node is the oracle
                if arg_definitions is not None:
                    for definition in arg_definitions:
                        # print the ast structure of the definitions
                        log.add("\n(line " + str(definition.lineno) + ")\narg" + str(_argument_position) + " = " + ast.dump(definition, indent='\t') + '\n')

                        # extract name
                        diff_test_function_name = self._getDifferentialOracleName(definition)
                        log.add("Extracted name arg" + str(_argument_position) + ": " + diff_test_function_name + "\n", mode=LOG_FINAL)

                        # create data entry
                        log.createEntry(node.lineno, self.last_function_definition_node.name, self.last_function_definition_node.lineno, assert_statement, _argument_position, definition.lineno, diff_test_function_name)


                # clear ingore list for next definition
                self.ignore_list = []

        # visit child nodes (neccessary?)
        self.generic_visit(node)
    
    def _getDefinition(self, node):
        """Check if the argument node is the oracle and return its definitions, 
        i.e. a list of each value that was assigned to it.
        
        Returns None if the node is not an oracle.
        """
        
        if node in self.nodes_visited:
            return []
        
        self.nodes_visited.append(node)
        
        definitions = []
            
        # if the argument uses self.evaluate, we can be sure that this is the argument to test
        # therefore the other argument is the oracle and we can stop analyzing this one
        if self._isSelf_Evaluate(node):
            return None
        
        # if the argument is a named variable we need to trace it back to its definition to see if it uses another
        # function or library for differential testing
        if isinstance(node, ast.Name):
            log.add(node.id + " is a named variable!")
            
            # to prevent loops, check if variable is on ignore list
            if node.id in self.ignore_list:
                log.add(node.id + " was found on the ignore list and will not be checked further.\n")
                return []
            
            # check if the variable is in the argument list of the function in which this test case was defined
            if node.id in self.last_func_arg_list:
                log.add(node.id + " will not be checked further because it is in the argument list of the parent function.\n")
                return []
                    
            # store name of the variable to search for and ignore it for later searches for this test case
            variable_name = node.id
            self.ignore_list.append(variable_name)
            
            # iterate through each variable assignment in the function that the assert is called from 
            # and that is above the assert statement, then return all assigned values of our assert argument variable
            for child in ast.walk(self.last_function_definition_node):
                if isinstance(child, ast.Assign) and child.lineno <= node.lineno:
                    for target in child.targets:
                        
                        #print("ASSIGN TARGET: " + ast.dump(target, indent='\t'))
                        
                        # for list assignments of the form e.g. [a,b] = func([a,b]) or
                        # for tuple assignments, i.e. a,b = c
                        if isinstance(target, ast.List) or isinstance(target, ast.Tuple):
                            for list_target in target.elts:
                                if isinstance(list_target, ast.Name) and list_target.id == variable_name:
                                    
                                    # check if the list uses self.evaluate as a function, i.e. self.evaluate([a,b])
                                    if self._isSelf_Evaluate(child.value):
                                        return None
                                    
                                    definitions.append(child.value)
                                    
                        
                        # for regular variable assignments
                        if isinstance(target, ast.Name) and target.id == variable_name:
                            
                            # if the assignment includes a self.evaluate statement, return None
                            if self._isSelf_Evaluate(child.value):
                                return None
                            
                            # otherwise return the value of the variable 
                            definitions.append(child.value)

            
        # if the argument is a function call, extract the function name and trace its arguments back to their definitions
        if isinstance(node, ast.Call):
            log.add("Argument is a function call!")
            log.add(ast.dump(node, indent='\t'))

            # Check variable that the function is called on, e.g. check a when oracle is a.mean():
            # for regular calls e.g. a.mean()
            if hasattr(node, 'func') and hasattr(node.func, 'value'):
                # check if the function is an imported one
                if self._checkImports(node.func.value):
                    definitions.append(node.func)
                
                # get all definitions of the variable
                variable_definition = self._getDefinition(node.func.value)
                
            # for calls to defined functions
            elif hasattr(node, 'func') and hasattr(node.func, 'id'):                              
                # node.func will contain a ast.Name, where the Name.id is the name of the defined function
                variable_definition = [node.func]
                
                
            # for double function calls, e.g. func(a)(b)
            elif hasattr(node, 'func') and hasattr(node.func, 'func'):
                variable_definition = self._getDefinition(node.func.func)
            
            # for subscripts, e.g. a[:2].mean()
            elif hasattr(node, 'value'):
                variable_definition = self._getDefinition(node.value)
                
            
            # append the found definitions or return None when an oracle was found
            if self._appendDefinitionsUtil(definitions, variable_definition) is False:
                return None
            
            
            # Check arguments of the function
            for arg in node.args:
                log.add("Checking function argument:")
                variable_definition = self._getDefinition(arg)
            
                # append the found definitions or return None when an oracle was found
                if self._appendDefinitionsUtil(definitions, variable_definition) is False:
                    return None       
        
        
        if isinstance(node, ast.Attribute):
            variable_definition = self._getDefinition(node.value)
            
            # append the found definitions or return None when an oracle was found
            if self._appendDefinitionsUtil(definitions, variable_definition) is False:
                return None
      
    
        # if the argument is a starred expression, e.g. *[a,b] or a subscript, e.g. a[:2]
        if isinstance(node, ast.Starred): #or isinstance(node, ast.Subscript):
            log.add("Argument is a starred expression or subscript!")
            
            definitions = self._getDefinition(node.value)
        
        
        # if the argument is a list
        if isinstance(node, ast.List) or isinstance(node, ast.Tuple):
            log.add("Argument is a list or tuple")        

            # get the definition of each element
            for element in node.elts:
                element_definition = self._getDefinition(element)
                
                # append the found definitions or return None when an oracle was found
                if self._appendDefinitionsUtil(definitions, element_definition) is False:
                    return None

        
        # if the argument is a constant we do not need to look at this argument further,
        # i.e. we return an empty list
        if isinstance(node, ast.Constant):
            log.add("Argument is a constant")
            
        
        if isinstance(node, ast.BinOp):
            log.add("Argument is a binary operation")
            definitions.append(node)
            
        
        # For compare operators: Check all values that are compared
        if isinstance(node, ast.Compare):
            log.add("Argument is a compare operation")
            
            # append left side
            definitions.append(node.left)
            
            # append right side
            if self._appendDefinitionsUtil(definitions, node.comparators) is False:
                return None
            
            
        
        if definitions is not None:    
        
            # trace the variables another level back:    
            copy_defs = set(definitions.copy())
            for definition in copy_defs:
                
                if definition in self.nodes_visited:
                    continue
                
                log.add("def: " + ast.dump(definition, indent='\t'))

                
                # if the definition is a starred expression, e.g. *[a,b] or a subscript, e.g. a[:2]
                if isinstance(definition, ast.Starred) or isinstance(definition, ast.Subscript):
                    log.add("Tracing starred/subscript definition back")

                    definitions.remove(definition)

                    variable_definition = self._getDefinition(definition.value)

                    # append the found definitions or return None when an oracle was found
                    if self._appendDefinitionsUtil(definitions, variable_definition) is False:
                        return None

                    
                # if the definition is a list     
                elif isinstance(definition, ast.List) or isinstance(definition, ast.Tuple):
                    log.add("Unwrapping list or tuple")
                    
                    definitions.remove(definition)
                    
                    for i, element in enumerate(definition.elts):
                        log.add("Element " + str(i) + ": ", end='')
                        element_definition = self._getDefinition(element)
                        
                        # append the found definitions or return None when an oracle was found
                        if self._appendDefinitionsUtil(definitions, element_definition) is False:
                            return None

    
                # if the definition is an if-else statement, e.g. arg = 20 if dt == dtypes.float16 else 10
                elif isinstance(definition, ast.IfExp):
                    log.add("Definition is an If-Else statement")
                    
                    definitions.remove(definition)
                
                    variable_definitions = []
                    log.add("If-Body: ", end='')
                    variable_definitions.append(self._getDefinition(definition.body))
                    log.add("Else-Body: ", end='')
                    variable_definitions.append(self._getDefinition(definition.orelse))
                    
                    for variable_definition in variable_definitions:
                        # append the found definitions or return None when an oracle was found
                        if self._appendDefinitionsUtil(definitions, variable_definition) is False:
                            return None
                
                # if the definition is an Attribute statement, e.g. arg.value
                elif isinstance(definition, ast.Attribute):
                    log.add("Definition is an Attribute")
                    
                    definitions.remove(definition)
                    
                    # Check each assign statement if it matches the definition, then get the value assigned
                    # e.g. arg.value = func() will append the func() node to the definitions
                    for child in ast.walk(self.last_function_definition_node):
                        if isinstance(child, ast.Assign):
                            for target in child.targets:
                                
                                while isinstance(target, ast.Attribute):
                                    # Iterate through attributes and compare
                                    if target.attr in ast.dump(definition):
                                        # append the assigned value (right hand side of the assignment)
                                        definitions.append(child.value)
                                        break
                                    
                                    # move to next attribute
                                    target = target.value
                                    
                
                # if the definition is a binary operation, e.g. a+b, get the definitions of the left and
                # right hand side of the operation
                elif isinstance(definition, ast.BinOp):
                    log.add("Definition is a binary operation")
                    
                    definitions.remove(definition)
                
                    variable_definitions = []
                    log.add("Left hand side: ", end='')
                    variable_definitions.append(self._getDefinition(definition.left))
                    log.add("Right hand side: ", end='')
                    variable_definitions.append(self._getDefinition(definition.right))
                    
                    for variable_definition in variable_definitions:
                        # append the found definitions or return None when an oracle was found
                        if self._appendDefinitionsUtil(definitions, variable_definition) is False:
                            return None
                        
                        
                # if the definition resolves to a constant
                elif isinstance(definition, ast.Constant):
                    log.add("Definition is a constant")
                    
                    definitions.remove(definition)
                    
                    
                # if the definition is a function name
                elif isinstance(definition, ast.Name):
                    log.add("Definition is a defined function name")
                    
                    definitions.remove(definition)

                    # check to make sure the function was not passed to this test case from the arguments of the 
                    # function that the test case was defined in
                    if definition.id in self.last_func_arg_list:
                        log.add("Definition is an argument of the parent function.")
                        return []

                    # search for its definition within the function and check the return value.
                    # if it is not within the function, it might be a function that is defined for the 
                    # entire file, e.g. the entropy function in distribution/bernoulli_test.py
                    found_return_value = False
                    for search_location in [self.last_function_definition_node, self.tree]:

                        for child in ast.walk(search_location):
                            if isinstance(child, ast.FunctionDef) and child.name == definition.id:

                                log.add("Function definition found: "+ ast.dump(child, indent='\t'))

                                # find the return value of the function
                                for field in ast.walk(child):
                                    if isinstance(field, ast.Return):
                                        log.add("Found return value: ", end='')
                                        found_return_value = True

                                        return_value_definition = self._getDefinition(field.value)

                                        # append the found definitions or return None when an oracle was found
                                        if self._appendDefinitionsUtil(definitions, return_value_definition) is False:
                                            return None

                        if found_return_value:
                            break

                            
                # if the definition is a function, continue the analysis
                elif isinstance(definition, ast.Call):
                    #definitions.remove(definition)
                    
                    call_definition = self._getDefinition(definition)
                        
                    # append the found definitions or return None when an oracle was found
                    if self._appendDefinitionsUtil(definitions, call_definition) is False:
                        return None

  
             
        return definitions
    
    
    
    def _checkImports(self, node):
        """Check if the node (here usually an ast.Name) is an imported class"""
        _node = copy.deepcopy(node)
        if isinstance(_node, ast.Attribute):
            _node = _node.value
            
        if not isinstance(_node, ast.Name):
            return False
        
        for child in ast.walk(self.tree):
            if isinstance(child, ast.Import) or isinstance(child, ast.ImportFrom):
                # Imports always contain the field 'names': Import( names=[ alias(name='numpy', asname='np') ])
                # compare the asname to the node.id
                for alias in child.names:
                    if (hasattr(alias, 'asname') and alias.asname == _node.id) or (hasattr(alias, 'name') and alias.name == _node.id):
                        log.add("Corresponding import found: \n" + ast.dump(child, indent="\t"))
                        return True
                    
        return False
    
    
    def _appendDefinitionsUtil(self, definitions, definitions_to_append):
        """Append the found definitions or return False when an oracle was found."""
         # check if it is the oracle
        if definitions_to_append is not None:
            # append definitions 
            [definitions.append(defin) for defin in definitions_to_append]

        # if it is not the oracle
        else:
            return False
            
        
    def _getDifferentialOracleName(self, node):
        """Get the name of the function used in the differential test case."""
        
        oracle_attributes = []
        oracle_name = ""
        
        # if it is a function call or attribute
        if isinstance(node, ast.Call) or isinstance(node, ast.Attribute):
            
            # for function: move into the function of the call node (ignoring the arguments of the function call)
            _node = node.func if isinstance(node, ast.Call) else node
            
            # if the function call has multiple attributes, i.e. np.linalg.solve()
            while isinstance(_node, ast.Attribute):
                # extract the name of the function
                oracle_attributes.append(_node.attr)
                
                # move another layer deeper into the node
                _node = _node.value
            
            # if this is the last attribute, i.e. we are at the deepest level of the call node
            if isinstance(_node, ast.Name):
                oracle_attributes.append(_node.id)
            
            # construct the oracle name by going through the reversed attributes array
            for attr in oracle_attributes[::-1]:
                oracle_name += attr + "."
            
            # remove the dot at the end
            oracle_name = oracle_name[:-1]
        
        
        # if it is a list comprehension, find func when node is e.g. [func(a) for a in b]
        if isinstance(node, ast.ListComp):
            # recursively call this function to extract the function name
            oracle_name = self._getDifferentialOracleName(node.elt)               
                
                
        # Catch errors: 
        
        # Should have checked the variables of binary operations e.g. arg1 = a/b
        if isinstance(node, ast.BinOp):
            oracle_name = "UNSUPPORTED Binary Operation"
            
        if isinstance(node, ast.UnaryOp):
            oracle_name = "UNSUPPORTED Unary Operation"
            
        # Should have been disregarded by the _getDefinition function
        if isinstance(node, ast.Constant):
            oracle_name = "UNSUPPORTED Constant"
            
        # Should have been analysed further by the _getDefinition function
        if isinstance(node, ast.Name):
            oracle_name = "UNSUPPORTED Name (named variable or defined function: " + node.id + ")"
        
        if isinstance(node, ast.Compare):
            oracle_name = "UNSUPPORTED Compare"
            
        if isinstance(node, ast.ListComp):
            oracle_name = "UNSUPPORTED List Comprehension"
        
        # return the oracle function name
        return oracle_name
                
        
    def _isSelf_Evaluate(self, node):
        """Check if the node is a self.evaluate call. If so, the node is not an oracle."""
        
        if isinstance(node, ast.Call) and isinstance(node.func, ast.Attribute) and node.func.attr == 'evaluate':
            log.add("Argument is an evaluate function call!")
            return True
        return False
        
    def visit_FunctionDef(self, node):
        
        # check if the function definition contains self
        if 'self' in ast.dump(node.args, indent='\t'):
            # remember the  last class-level function definition seen
            self.last_function_definition_node = node
            
            # store all function arguments to check if we encounter one later
            self.last_func_arg_list = [n.arg for n in node.args.args]
            
            # TESTING: to catch cases
            if node.args.posonlyargs != [] or node.args.kwonlyargs != []:
                log.add("NEW ARGS FOUND", mode=LOG_ALL)
            
        # catch the case where the first function of a file is not a class member 
        elif self.last_function_definition_node == None:
            self.last_function_definition_node = node
            
        # visit child nodes
        self.generic_visit(node)


# For debugging on a single file:

# Initialize custom logger
# Use the print mode LOG_FINAL for final output and LOG_ALL for debugging
log = CustomLogger(LOG_ALL)

# start the tree traversal
TreeTraverser(tree).visit(tree)

log.log.close()
# Out:
# ______________assertEqual__(line 57)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Call(
# 					func=Attribute(
# 						value=Name(id='gamma', ctx=Load()),
# 						attr='batch_shape_tensor',
# 						ctx=Load()),
# 					args=[],
# 					keywords=[])],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=5)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaShape
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# ______________assertEqual__(line 58)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Attribute(
# 			value=Name(id='gamma', ctx=Load()),
# 			attr='batch_shape',
# 			ctx=Load()),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='tensor_shape', ctx=Load()),
# 				attr='TensorShape',
# 				ctx=Load()),
# 			args=[
# 				List(
# 					elts=[
# 						Constant(value=5)],
# 					ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaShape
#
# Argument 1:
# gamma is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 55)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='tensor_shape', ctx=Load()),
# 		attr='TensorShape',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=5)],
# 			ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.framework',
# 	names=[
# 		alias(name='tensor_shape')],
# 	level=0)
# tensor_shape is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# def: Attribute(
# 	value=Name(id='tensor_shape', ctx=Load()),
# 	attr='TensorShape',
# 	ctx=Load())
# Definition is an Attribute
# ______________assertAllEqual__(line 59)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Call(
# 					func=Attribute(
# 						value=Name(id='gamma', ctx=Load()),
# 						attr='event_shape_tensor',
# 						ctx=Load()),
# 					args=[],
# 					keywords=[])],
# 			keywords=[]),
# 		List(elts=[], ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaShape
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is a list or tuple
# ______________assertEqual__(line 60)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Attribute(
# 			value=Name(id='gamma', ctx=Load()),
# 			attr='event_shape',
# 			ctx=Load()),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='tensor_shape', ctx=Load()),
# 				attr='TensorShape',
# 				ctx=Load()),
# 			args=[
# 				List(elts=[], ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaShape
#
# Argument 1:
# gamma is a named variable!
#
# (line 55)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='tensor_shape', ctx=Load()),
# 		attr='TensorShape',
# 		ctx=Load()),
# 	args=[
# 		List(elts=[], ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.framework',
# 	names=[
# 		alias(name='tensor_shape')],
# 	level=0)
# tensor_shape is a named variable!
# Checking function argument:
# Argument is a list or tuple
# def: Attribute(
# 	value=Name(id='tensor_shape', ctx=Load()),
# 	attr='TensorShape',
# 	ctx=Load())
# Definition is an Attribute
# ______________assertEqual__(line 71)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='log_pdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDF
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='log_pdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# log_pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# x is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='array',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='log_prob',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 70)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.log_prob
#
#
# (line 69)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# (line 68)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
#
# Extracted name arg1: np.array
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# ______________assertEqual__(line 73)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='pdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDF
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='pdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='prob',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 72)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.prob
#
#
# (line 69)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# (line 68)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
#
# Extracted name arg1: np.array
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# ______________assertAllClose__(line 77)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Name(id='log_pdf', ctx=Load())],
# 			keywords=[]),
# 		Name(id='expected_log_pdf', ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDF
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# expected_log_pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# stats is a named variable!
# Checking function argument:
# x is a named variable!
# Checking function argument:
# alpha_v is a named variable!
# def: Constant(value=2.0)
# Definition is a constant
#
# (line 76)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.logpdf
#
#
# (line 68)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
#
# Extracted name arg2: np.array
#
# ______________assertAllClose__(line 78)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Name(id='pdf', ctx=Load())],
# 			keywords=[]),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='exp',
# 				ctx=Load()),
# 			args=[
# 				Name(id='expected_log_pdf', ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaLogPDF
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='exp',
# 		ctx=Load()),
# 	args=[
# 		Name(id='expected_log_pdf', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# expected_log_pdf is a named variable!
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='exp',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 76)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.logpdf
#
# ______________assertEqual__(line 90)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='log_pdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6),
# 				Constant(value=2)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensional
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='log_pdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# log_pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Call(
# 		func=Attribute(
# 			value=Name(id='np', ctx=Load()),
# 			attr='array',
# 			ctx=Load()),
# 		args=[
# 			List(
# 				elts=[
# 					List(
# 						elts=[
# 							Constant(value=2.5),
# 							Constant(value=2.5),
# 							Constant(value=4.0),
# 							Constant(value=0.1),
# 							Constant(value=1.0),
# 							Constant(value=2.0)],
# 						ctx=Load())],
# 				ctx=Load())],
# 		keywords=[
# 			keyword(
# 				arg='dtype',
# 				value=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='float32',
# 					ctx=Load()))]),
# 	attr='T',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='log_prob',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 88)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.log_prob
#
#
# (line 87)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# ______________assertEqual__(line 93)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='pdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6),
# 				Constant(value=2)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensional
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='pdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Call(
# 		func=Attribute(
# 			value=Name(id='np', ctx=Load()),
# 			attr='array',
# 			ctx=Load()),
# 		args=[
# 			List(
# 				elts=[
# 					List(
# 						elts=[
# 							Constant(value=2.5),
# 							Constant(value=2.5),
# 							Constant(value=4.0),
# 							Constant(value=0.1),
# 							Constant(value=1.0),
# 							Constant(value=2.0)],
# 						ctx=Load())],
# 				ctx=Load())],
# 		keywords=[
# 			keyword(
# 				arg='dtype',
# 				value=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='float32',
# 					ctx=Load()))]),
# 	attr='T',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='prob',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 91)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.prob
#
#
# (line 87)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# ______________assertAllClose__(line 97)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Name(id='log_pdf_values', ctx=Load()),
# 		Name(id='expected_log_pdf', ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensional
#
# Argument 1:
# log_pdf_values is a named variable!
# Argument is an evaluate function call!
#
# Argument 2:
# expected_log_pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# stats is a named variable!
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Call(
# 		func=Attribute(
# 			value=Name(id='np', ctx=Load()),
# 			attr='array',
# 			ctx=Load()),
# 		args=[
# 			List(
# 				elts=[
# 					List(
# 						elts=[
# 							Constant(value=2.5),
# 							Constant(value=2.5),
# 							Constant(value=4.0),
# 							Constant(value=0.1),
# 							Constant(value=1.0),
# 							Constant(value=2.0)],
# 						ctx=Load())],
# 				ctx=Load())],
# 		keywords=[
# 			keyword(
# 				arg='dtype',
# 				value=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='float32',
# 					ctx=Load()))]),
# 	attr='T',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# alpha_v is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.0),
# 				Constant(value=4.0)],
# 			ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.0),
# 				Constant(value=4.0)],
# 			ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='array',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 96)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.logpdf
#
#
# (line 84)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.0),
# 				Constant(value=4.0)],
# 			ctx=Load())],
# 	keywords=[])
#
# Extracted name arg2: np.array
#
# ______________assertAllClose__(line 98)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Name(id='pdf_values', ctx=Load()),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='exp',
# 				ctx=Load()),
# 			args=[
# 				Name(id='expected_log_pdf', ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensional
#
# Argument 1:
# pdf_values is a named variable!
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='exp',
# 		ctx=Load()),
# 	args=[
# 		Name(id='expected_log_pdf', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# expected_log_pdf is a named variable!
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='exp',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 96)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.logpdf
#
# ______________assertEqual__(line 110)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='log_pdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6),
# 				Constant(value=2)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensionalBroadcasting
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='log_pdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# log_pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Call(
# 		func=Attribute(
# 			value=Name(id='np', ctx=Load()),
# 			attr='array',
# 			ctx=Load()),
# 		args=[
# 			List(
# 				elts=[
# 					List(
# 						elts=[
# 							Constant(value=2.5),
# 							Constant(value=2.5),
# 							Constant(value=4.0),
# 							Constant(value=0.1),
# 							Constant(value=1.0),
# 							Constant(value=2.0)],
# 						ctx=Load())],
# 				ctx=Load())],
# 		keywords=[
# 			keyword(
# 				arg='dtype',
# 				value=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='float32',
# 					ctx=Load()))]),
# 	attr='T',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='log_prob',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 108)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='log_prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.log_prob
#
#
# (line 107)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# ______________assertEqual__(line 113)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='pdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6),
# 				Constant(value=2)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensionalBroadcasting
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='pdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Call(
# 		func=Attribute(
# 			value=Name(id='np', ctx=Load()),
# 			attr='array',
# 			ctx=Load()),
# 		args=[
# 			List(
# 				elts=[
# 					List(
# 						elts=[
# 							Constant(value=2.5),
# 							Constant(value=2.5),
# 							Constant(value=4.0),
# 							Constant(value=0.1),
# 							Constant(value=1.0),
# 							Constant(value=2.0)],
# 						ctx=Load())],
# 				ctx=Load())],
# 		keywords=[
# 			keyword(
# 				arg='dtype',
# 				value=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='float32',
# 					ctx=Load()))]),
# 	attr='T',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='prob',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 111)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='prob',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.prob
#
#
# (line 107)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# ______________assertAllClose__(line 118)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Name(id='log_pdf_values', ctx=Load()),
# 		Name(id='expected_log_pdf', ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensionalBroadcasting
#
# Argument 1:
# log_pdf_values is a named variable!
# Argument is an evaluate function call!
#
# Argument 2:
# expected_log_pdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# stats is a named variable!
# Checking function argument:
# x is a named variable!
# def: Attribute(
# 	value=Call(
# 		func=Attribute(
# 			value=Name(id='np', ctx=Load()),
# 			attr='array',
# 			ctx=Load()),
# 		args=[
# 			List(
# 				elts=[
# 					List(
# 						elts=[
# 							Constant(value=2.5),
# 							Constant(value=2.5),
# 							Constant(value=4.0),
# 							Constant(value=0.1),
# 							Constant(value=1.0),
# 							Constant(value=2.0)],
# 						ctx=Load())],
# 				ctx=Load())],
# 		keywords=[
# 			keyword(
# 				arg='dtype',
# 				value=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='float32',
# 					ctx=Load()))]),
# 	attr='T',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# alpha_v is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.0),
# 				Constant(value=4.0)],
# 			ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.0),
# 				Constant(value=4.0)],
# 			ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='array',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 117)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.logpdf
#
#
# (line 104)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.0),
# 				Constant(value=4.0)],
# 			ctx=Load())],
# 	keywords=[])
#
# Extracted name arg2: np.array
#
# ______________assertAllClose__(line 119)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Name(id='pdf_values', ctx=Load()),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='exp',
# 				ctx=Load()),
# 			args=[
# 				Name(id='expected_log_pdf', ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaLogPDFMultidimensionalBroadcasting
#
# Argument 1:
# pdf_values is a named variable!
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='exp',
# 		ctx=Load()),
# 	args=[
# 		Name(id='expected_log_pdf', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# expected_log_pdf is a named variable!
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='exp',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 117)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='logpdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.logpdf
#
# ______________assertEqual__(line 131)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='cdf', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=6)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaCDF
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='cdf', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# cdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='cdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='cdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# x is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='array',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='cdf',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 130)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='cdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: gamma.cdf
#
#
# (line 129)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# (line 127)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
#
# Extracted name arg1: np.array
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# ______________assertAllClose__(line 135)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Name(id='cdf', ctx=Load())],
# 			keywords=[]),
# 		Name(id='expected_cdf', ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaCDF
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# expected_cdf is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='cdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='cdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# stats is a named variable!
# Checking function argument:
# x is a named variable!
# Checking function argument:
# alpha_v is a named variable!
# def: Constant(value=2.0)
# Definition is a constant
#
# (line 134)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='cdf',
# 		ctx=Load()),
# 	args=[
# 		Name(id='x', ctx=Load()),
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
#
# Extracted name arg2: stats.gamma.cdf
#
#
# (line 127)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=2.5),
# 				Constant(value=2.5),
# 				Constant(value=4.0),
# 				Constant(value=0.1),
# 				Constant(value=1.0),
# 				Constant(value=2.0)],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='dtype',
# 			value=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='float32',
# 				ctx=Load()))])
#
# Extracted name arg2: np.array
#
# ______________assertEqual__(line 141)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Call(
# 					func=Attribute(
# 						value=Name(id='gamma', ctx=Load()),
# 						attr='mean',
# 						ctx=Load()),
# 					args=[],
# 					keywords=[]),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		Tuple(
# 			elts=[
# 				Constant(value=3)],
# 			ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaMean
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Call(
# 			func=Attribute(
# 				value=Name(id='gamma', ctx=Load()),
# 				attr='mean',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[]),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma', ctx=Load()),
# 		attr='mean',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha_v', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta_v', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha_v', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta_v', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='gamma', ctx=Load()),
# 	attr='mean',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 140)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha_v', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta_v', ctx=Load()))])
#
# Extracted name arg1: gamma_lib.Gamma
#
#
# Argument 2:
# Argument is a list or tuple
# Argument is a constant
# ______________assertAllClose__(line 145)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Call(
# 					func=Attribute(
# 						value=Name(id='gamma', ctx=Load()),
# 						attr='mean',
# 						ctx=Load()),
# 					args=[],
# 					keywords=[])],
# 			keywords=[]),
# 		Name(id='expected_means', ctx=Load())],
# 	keywords=[])
#
# Found in: testGammaMean
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# expected_means is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='mean',
# 		ctx=Load()),
# 	args=[
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='mean',
# 		ctx=Load()),
# 	args=[
# 		Name(id='alpha_v', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Name(id='beta_v', ctx=Load())))])
# stats is a named variable!
# Checking function argument:
# alpha_v is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=1.0),
# 				Constant(value=3.0),
# 				Constant(value=2.5)],
# 			ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=1.0),
# 				Constant(value=3.0),
# 				Constant(value=2.5)],
# 			ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# Argument is a constant
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='array',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 144)
# arg2 = Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='mean',
# 		ctx=Load()),
# 	args=[
# 		Name(id='alpha_v', ctx=Load())],
# ...
# 							elts=[
# 								List(
# 									elts=[
# 										Constant(value=5.0),
# 										Constant(value=5.0)],
# 									ctx=Load()),
# 								List(
# 									elts=[
# 										Constant(value=6.0),
# 										Constant(value=6.0)],
# 									ctx=Load())],
# 							ctx=Load())],
# 					keywords=[])))])
# stats is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='sample_vals', ctx=Load()),
# 		attr='mean',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='axis',
# 			value=Constant(value=0))])
# sample_vals is a named variable!
# Argument is an evaluate function call!
# ______________assertAllClose__(line 323)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Attribute(
# 					value=Name(id='stats', ctx=Load()),
# 					attr='gamma',
# 					ctx=Load()),
# 				attr='var',
# 				ctx=Load()),
# 			args=[
# 				List(
# 					elts=[
# 						List(
# 							elts=[
# 								Constant(value=7.0),
# 								Constant(value=11.0)],
# 							ctx=Load()),
# 						List(
# 							elts=[
# 								Constant(value=7.0),
# 								Constant(value=11.0)],
# 							ctx=Load())],
# 					ctx=Load())],
# 			keywords=[
# 				keyword(
# 					arg='scale',
# 					value=BinOp(
# 						left=Constant(value=1),
# 						op=Div(),
# 						right=Call(
# 							func=Attribute(
# 								value=Name(id='np', ctx=Load()),
# 								attr='array',
# 								ctx=Load()),
# 							args=[
# 								List(
# 									elts=[
# 										List(
# 											elts=[
# 												Constant(value=5.0),
# 												Constant(value=5.0)],
# 											ctx=Load()),
# 										List(
# 											elts=[
# 												Constant(value=6.0),
# 												Constant(value=6.0)],
# 											ctx=Load())],
# 									ctx=Load())],
# 							keywords=[])))]),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='sample_vals', ctx=Load()),
# 				attr='var',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[
# 				keyword(
# 					arg='axis',
# 					value=Constant(value=0))])],
# 	keywords=[
# 		keyword(
# 			arg='atol',
# 			value=Constant(value=0.1))])
#
# Found in: testGammaPdfOfSampleMultiDims
#
# Argument 1:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Attribute(
# 			value=Name(id='stats', ctx=Load()),
# 			attr='gamma',
# 			ctx=Load()),
# 		attr='var',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				List(
# 					elts=[
# 						Constant(value=7.0),
# 						Constant(value=11.0)],
# 					ctx=Load()),
# 				List(
# 					elts=[
# 						Constant(value=7.0),
# 						Constant(value=11.0)],
# 					ctx=Load())],
# 			ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='scale',
# 			value=BinOp(
# 				left=Constant(value=1),
# 				op=Div(),
# 				right=Call(
# 					func=Attribute(
# 						value=Name(id='np', ctx=Load()),
# 						attr='array',
# 						ctx=Load()),
# 					args=[
# 						List(
# 							elts=[
# 								List(
# 									elts=[
# 										Constant(value=5.0),
# 										Constant(value=5.0)],
# 									ctx=Load()),
# 								List(
# 									elts=[
# 										Constant(value=6.0),
# 										Constant(value=6.0)],
# 									ctx=Load())],
# 							ctx=Load())],
# 					keywords=[])))])
# stats is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='sample_vals', ctx=Load()),
# 		attr='var',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='axis',
# 			value=Constant(value=0))])
# sample_vals is a named variable!
# Argument is an evaluate function call!
# ______________assertNear__(line 337)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertNear',
# 		ctx=Load()),
# 	args=[
# 		Constant(value=1.0),
# 		Name(id='total', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='err',
# 			value=Name(id='err', ctx=Load()))])
#
# Found in: _assertIntegral
#
# Argument 1:
# Argument is a constant
#
# Argument 2:
# total is a named variable!
# def: Constant(value=0)
# Definition is a constant
# ______________assertAllEqual__(line 358)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Call(
# 					func=Attribute(
# 						value=Name(id='nn_ops', ctx=Load()),
# 						attr='softplus',
# 						ctx=Load()),
# 					args=[
# 						Name(id='alpha_v', ctx=Load())],
# 					keywords=[])],
# 			keywords=[]),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Attribute(
# 					value=Name(id='gamma', ctx=Load()),
# 					attr='concentration',
# 					ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaWithSoftplusConcentrationRate
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is an evaluate function call!
# ______________assertAllEqual__(line 361)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllEqual',
# 		ctx=Load()),
# 	args=[
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Call(
# 					func=Attribute(
# 						value=Name(id='nn_ops', ctx=Load()),
# 						attr='softplus',
# 						ctx=Load()),
# 					args=[
# 						Name(id='beta_v', ctx=Load())],
# 					keywords=[])],
# 			keywords=[]),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='self', ctx=Load()),
# 				attr='evaluate',
# 				ctx=Load()),
# 			args=[
# 				Attribute(
# 					value=Name(id='gamma', ctx=Load()),
# 					attr='rate',
# 					ctx=Load())],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaWithSoftplusConcentrationRate
#
# Argument 1:
# Argument is an evaluate function call!
#
# Argument 2:
# Argument is an evaluate function call!
# ______________assertEqual__(line 381)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertEqual',
# 		ctx=Load()),
# 	args=[
# 		Attribute(
# 			value=Name(id='beta0', ctx=Load()),
# 			attr='shape',
# 			ctx=Load()),
# 		Call(
# 			func=Attribute(
# 				value=Name(id='kl_actual', ctx=Load()),
# 				attr='get_shape',
# 				ctx=Load()),
# 			args=[],
# 			keywords=[])],
# 	keywords=[])
#
# Found in: testGammaGammaKL
#
# Argument 1:
# beta0 is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=1.0),
# 				Constant(value=2.0),
# 				Constant(value=3.0),
# 				Constant(value=1.5),
# 				Constant(value=2.5),
# 				Constant(value=3.5)],
# 			ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=1.0),
# 				Constant(value=2.0),
# 				Constant(value=3.0),
# 				Constant(value=1.5),
# 				Constant(value=2.5),
# 				Constant(value=3.5)],
# 			ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# Import(
# 	names=[
# 		alias(name='numpy', asname='np')])
# np is a named variable!
# Checking function argument:
# Argument is a list or tuple
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# Argument is a constant
# def: Attribute(
# 	value=Name(id='np', ctx=Load()),
# 	attr='array',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 366)
# arg1 = Call(
# 	func=Attribute(
# 		value=Name(id='np', ctx=Load()),
# 		attr='array',
# 		ctx=Load()),
# 	args=[
# 		List(
# 			elts=[
# 				Constant(value=1.0),
# 				Constant(value=2.0),
# 				Constant(value=3.0),
# 				Constant(value=1.5),
# 				Constant(value=2.5),
# 				Constant(value=3.5)],
# 			ctx=Load())],
# 	keywords=[])
#
# Extracted name arg1: np.array
#
#
# Argument 2:
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='kl_actual', ctx=Load()),
# 		attr='get_shape',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[])
# kl_actual is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='kullback_leibler', ctx=Load()),
# 		attr='kl_divergence',
# 		ctx=Load()),
# 	args=[
# 		Name(id='g0', ctx=Load()),
# 		Name(id='g1', ctx=Load())],
# 	keywords=[])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='kullback_leibler', ctx=Load()),
# 		attr='kl_divergence',
# 		ctx=Load()),
# 	args=[
# 		Name(id='g0', ctx=Load()),
# 		Name(id='g1', ctx=Load())],
# 	keywords=[])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='kullback_leibler')],
# 	level=0)
# kullback_leibler is a named variable!
# Checking function argument:
# g0 is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha0', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta0', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha0', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta0', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# Checking function argument:
# g1 is a named variable!
# def: Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha1', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta1', ctx=Load()))])
# Argument is a function call!
# Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha1', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta1', ctx=Load()))])
# Corresponding import found:
# ImportFrom(
# 	module='tensorflow.python.ops.distributions',
# 	names=[
# 		alias(name='gamma', asname='gamma_lib')],
# 	level=0)
# gamma_lib is a named variable!
# gamma_lib was found on the ignore list and will not be checked further.
#
# def: Attribute(
# 	value=Name(id='gamma_lib', ctx=Load()),
# 	attr='Gamma',
# 	ctx=Load())
# Definition is an Attribute
# def: Attribute(
# 	value=Name(id='kullback_leibler', ctx=Load()),
# 	attr='kl_divergence',
# 	ctx=Load())
# Definition is an Attribute
#
# (line 376)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='kullback_leibler', ctx=Load()),
# 		attr='kl_divergence',
# 		ctx=Load()),
# 	args=[
# 		Name(id='g0', ctx=Load()),
# 		Name(id='g1', ctx=Load())],
# 	keywords=[])
#
# Extracted name arg2: kullback_leibler.kl_divergence
# (line 372)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha0', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta0', ctx=Load()))])
#
# Extracted name arg2: gamma_lib.Gamma
#
#
# (line 373)
# arg2 = Call(
# 	func=Attribute(
# 		value=Name(id='gamma_lib', ctx=Load()),
# 		attr='Gamma',
# 		ctx=Load()),
# 	args=[],
# 	keywords=[
# 		keyword(
# 			arg='concentration',
# 			value=Name(id='alpha1', ctx=Load())),
# 		keyword(
# 			arg='rate',
# 			value=Name(id='beta1', ctx=Load()))])
#
# Extracted name arg2: gamma_lib.Gamma
#
# ______________assertAllClose__(line 392)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Name(id='kl_expected', ctx=Load()),
# 		Name(id='kl_actual_', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='atol',
# 			value=Constant(value=0.0)),
# 		keyword(
# 			arg='rtol',
# 			value=Constant(value=1e-06))])
#
# Found in: testGammaGammaKL
#
# Argument 1:
# kl_expected is a named variable!
# def: BinOp(
# 	left=BinOp(
# 		left=BinOp(
# 			left=BinOp(
# 				left=BinOp(
# 					left=BinOp(
# 						left=BinOp(
# 							left=Name(id='alpha0', ctx=Load()),
# 							op=Sub(),
# 							right=Name(id='alpha1', ctx=Load())),
# 						op=Mult(),
# 						right=Call(
# 							func=Attribute(
# 								value=Name(id='special', ctx=Load()),
# 								attr='digamma',
# 								ctx=Load()),
# 							args=[
# 								Name(id='alpha0', ctx=Load())],
# 							keywords=[])),
# 					op=Add(),
# 					right=Call(
# 						func=Attribute(
# 							value=Name(id='special', ctx=Load()),
# 							attr='gammaln',
# 							ctx=Load()),
# 						args=[
# 							Name(id='alpha1', ctx=Load())],
# 						keywords=[])),
# 				op=Sub(),
# 				right=Call(
# 					func=Attribute(
# 						value=Name(id='special', ctx=Load()),
# 						attr='gammaln',
# 						ctx=Load()),
# 					args=[
# 						Name(id='alpha0', ctx=Load())],
# 					keywords=[])),
# 			op=Add(),
# 			right=BinOp(
# 				left=Name(id='alpha1', ctx=Load()),
# 				op=Mult(),
# 				right=Call(
# 					func=Attribute(
# 						value=Name(id='np', ctx=Load()),
# 						attr='log',
# 						ctx=Load()),
# 					args=[
# 						Name(id='beta0', ctx=Load())],
# 					keywords=[]))),
# 		op=Sub(),
# 		right=BinOp(
# 			left=Name(id='alpha1', ctx=Load()),
# 			op=Mult(),
# 			right=Call(
# 				func=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='log',
# 					ctx=Load()),
# 				args=[
# 					Name(id='beta1', ctx=Load())],
# 				keywords=[]))),
# 	op=Add(),
# 	right=BinOp(
# 		left=Name(id='alpha0', ctx=Load()),
# 		op=Mult(),
# 		right=BinOp(
# 			left=BinOp(
# 				left=Name(id='beta1', ctx=Load()),
# 				op=Div(),
# 				right=Name(id='beta0', ctx=Load())),
# 			op=Sub(),
# 			right=Constant(value=1.0))))
# Definition is a binary operation
# Left hand side: Argument is a binary operation
# Right hand side: Argument is a binary operation
#
# (line 385)
# arg1 = BinOp(
# 	left=BinOp(
# 		left=BinOp(
# 			left=BinOp(
# 				left=BinOp(
# 					left=BinOp(
# 						left=Name(id='alpha0', ctx=Load()),
# 						op=Sub(),
# 						right=Name(id='alpha1', ctx=Load())),
# 					op=Mult(),
# 					right=Call(
# 						func=Attribute(
# 							value=Name(id='special', ctx=Load()),
# 							attr='digamma',
# 							ctx=Load()),
# 						args=[
# 							Name(id='alpha0', ctx=Load())],
# 						keywords=[])),
# 				op=Add(),
# 				right=Call(
# 					func=Attribute(
# 						value=Name(id='special', ctx=Load()),
# 						attr='gammaln',
# 						ctx=Load()),
# 					args=[
# 						Name(id='alpha1', ctx=Load())],
# 					keywords=[])),
# 			op=Sub(),
# 			right=Call(
# 				func=Attribute(
# 					value=Name(id='special', ctx=Load()),
# 					attr='gammaln',
# 					ctx=Load()),
# 				args=[
# 					Name(id='alpha0', ctx=Load())],
# 				keywords=[])),
# 		op=Add(),
# 		right=BinOp(
# 			left=Name(id='alpha1', ctx=Load()),
# 			op=Mult(),
# 			right=Call(
# 				func=Attribute(
# 					value=Name(id='np', ctx=Load()),
# 					attr='log',
# 					ctx=Load()),
# 				args=[
# 					Name(id='beta0', ctx=Load())],
# 				keywords=[]))),
# 	op=Sub(),
# 	right=BinOp(
# 		left=Name(id='alpha1', ctx=Load()),
# 		op=Mult(),
# 		right=Call(
# 			func=Attribute(
# 				value=Name(id='np', ctx=Load()),
# 				attr='log',
# 				ctx=Load()),
# 			args=[
# 				Name(id='beta1', ctx=Load())],
# 			keywords=[])))
#
# Extracted name arg1: UNSUPPORTED Binary Operation
#
#
# (line 390)
# arg1 = BinOp(
# 	left=Name(id='alpha0', ctx=Load()),
# 	op=Mult(),
# 	right=BinOp(
# 		left=BinOp(
# 			left=Name(id='beta1', ctx=Load()),
# 			op=Div(),
# 			right=Name(id='beta0', ctx=Load())),
# 		op=Sub(),
# 		right=Constant(value=1.0)))
#
# Extracted name arg1: UNSUPPORTED Binary Operation
#
#
# Argument 2:
# kl_actual_ is a named variable!
# Argument is an evaluate function call!
# ______________assertAllClose__(line 393)______________
# Call(
# 	func=Attribute(
# 		value=Name(id='self', ctx=Load()),
# 		attr='assertAllClose',
# 		ctx=Load()),
# 	args=[
# 		Name(id='kl_sample_', ctx=Load()),
# 		Name(id='kl_actual_', ctx=Load())],
# 	keywords=[
# 		keyword(
# 			arg='atol',
# 			value=Constant(value=0.0)),
# 		keyword(
# 			arg='rtol',
# 			value=Constant(value=0.1))])
#
# Found in: testGammaGammaKL
#
# Argument 1:
# kl_sample_ is a named variable!
# Argument is an evaluate function call!
#
# Argument 2:
# kl_actual_ is a named variable!
# Argument is an evaluate function call!

# %% [markdown]
# ## Applying the function extraction to all TensorFlow testing files
#
# Now that our function extraction via tree traversal works on single source files, we can now create a list of potential differential testing functions for all TensorFlow testing files. This will be in the form of a data table with the following entries:
#
# | File | Assert line number | Found in Function | Function definition line number | Assert Statement Type | Oracle argument position | Differential Function line number | Extracted Differential Test Function |
# |:----:|:-----------:|:-----------------:|:--------:|:-------------:|:-------------------:|:-------------------------------:|:----:|
# |kernel_tests/distributions/student_t_test.py| 75 |testStudentPDFAndLogPDF| 52 | assertAllClose|1|73|stats.t.logpdf|
#
# To do this we will first write code that will go through each subdirectory and file and return the file paths of all `.py` files that contain 'test' in their name:

# %%
# fill test_files with the file paths to all python files relative to library_root that contain 'test' in their name 
test_files = []
for subdir, _, files in os.walk(library_root):
    #print(subdir)
    for file in files:
        if file.endswith(".py") and 'test' in file:
            relative_dir = subdir.replace(library_root, '')
            filepath = relative_dir + os.sep + file
            test_files.append(filepath) 
            #print("\t"+filepath)

# %%
# Initialize custom logger
log = CustomLogger(LOG_NONE)

error_list = []
# go through each file and extract data
for file in tqdm(test_files):
    # set file path that appears in the data entries for this file 
    log.set_file_path_variable(file)
    log.add("<<<<<<<<<<<<" + file + ">>>>>>>>>>>>", LOG_FINAL)
    
    source = open(library_root + file, encoding="utf8")
    
    try:
        # generate abstract syntax tree and start the tree traversal as before
        tree = ast.parse(source.read())
        TreeTraverser(tree).visit(tree)
    
    except:
        error_list.append(file)

# print collected data and save to csv
#print(log.get_data())
print("Remaining errors in files: " + str(len(error_list)) + " " + str(error_list))
log.save_data_to_csv(save_data_to)
# Out:
#  30%|████████████▎                            | 53/176 [02:16<05:23,  2.63s/it]
# NEW ARGS FOUND
# 100%|████████████████████████████████████████| 176/176 [10:36<00:00,  3.61s/it]
# Remaining errors in files: 4 ['\\core\\tests\\test_defchararray.py', '\\core\\tests\\test_multiarray.py', '\\polynomial\\tests\\test_printing.py', '\\tests\\test_ctypeslib.py']
# Data saved to extracted_data/numpy_data.csv

# %% [markdown]
# ## Simple search for differential tests using other Deep Learning Libraries

# %%
for file in test_files:
    source = open(library_root + file, encoding="utf8").read()

    string_to_find = 'scipy'
    if string_to_find in source:
        print(string_to_find + " found in: " + file)
# Out:
# scipy found in: \core\tests\test_multiarray.py
# scipy found in: \core\tests\test_regression.py
# scipy found in: \distutils\tests\test_exec_command.py
# scipy found in: \lib\tests\test_io.py
# scipy found in: \testing\_private\nosetester.py

# %%
for file in test_files:
    
    string_to_find = 'keras'
    if not 'test' in file[13:]:
        print(file[13:])

# %%
# !start {library_root}/core/tests
